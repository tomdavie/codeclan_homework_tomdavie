# %% [markdown]
# Q1

# %%
shopping = ["spam", "ham", "eggs", "ham"]

# %%
shopping[1]
# Out:
# 'ham'

# %%
shopping[0:3]
# Out:
# ['spam', 'ham', 'eggs']

# %%
shopping[-1]
# Out:
# 'ham'

# %% [markdown]
# Q2

# %%
stops = ["Croy", "Cumbernauld", "Falkirk High", "Linlithgow", "Livingston", "Haymarket"]

# %%
stops.append("Edinburgh Waverly")
stops
# Out:
# ['Croy',
#  'Cumbernauld',
#  'Falkirk High',
#  'Linlithgow',
#  'Livingston',
#  'Haymarket',
#  'Edinburgh Waverly']

# %%
x = "Queen Street"

stops.insert(0,x)
print(stops)
# Out:
# ['Queen Street', 'Croy', 'Cumbernauld', 'Falkirk High', 'Linlithgow', 'Livingston', 'Haymarket', 'Edinburgh Waverly']

# %%
stops.index("Croy")
# Out:
# 1

# %%
x = "Polmont"

stops.insert(4, x)
stops
# Out:
# ['Queen Street',
#  'Croy',
#  'Cumbernauld',
#  'Falkirk High',
#  'Polmont',
#  'Linlithgow',
#  'Livingston',
#  'Haymarket',
#  'Edinburgh Waverly']

# %%
stops.remove("Haymarket")
stops
# Out:
# ['Queen Street',
#  'Croy',
#  'Cumbernauld',
#  'Falkirk High',
#  'Polmont',
#  'Linlithgow',
#  'Livingston',
#  'Edinburgh Waverly']

# %%
stops.clear()
stops
# Out:
# []

# %% [markdown]
# Q3

# %%
person = {"name": "Steph", "age": 31, "Instructor" : True}

# %%
person.keys()
# Out:
# dict_keys(['name', 'age', 'Instructor'])

# %%
person.values()
# Out:
# dict_values(['Steph', 31, True])

# %%
person.items()
# Out:
# dict_items([('name', 'Steph'), ('age', 31), ('Instructor', True)])

# %%
person["name"]
# Out:
# 'Steph'

# %%
person.update({"name": "Steph", "age": 31, "Instructor" : True, "email": "steph@codeclan.com"})
person
# Out:
# {'name': 'Steph', 'age': 31, 'Instructor': True, 'email': 'steph@codeclan.com'}

# %%
person

del person["Instructor"]
person
# Out:
# {'name': 'Steph', 'age': 31, 'email': 'steph@codeclan.com'}

# %% [markdown]
# Q4

# %%
numbers = [1, 6, 2, 2, 7, 1, 6, 13, 99, 7]

# %%
even_numbers = []

for number in numbers:
    if number %2 == 0:
        even_numbers.append(number)
        
print(even_numbers)
# Out:
# [6, 2, 2, 6]

# %%
largest = max(numbers) 
smallest = min(number)

print(largest-smallest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-beca213db7f8> in <module>
#       1 largest = max(numbers)
# ----> 2 smallest = min(number)
#       3
#       4 print(largest-smallest)
#
# TypeError: 'int' object is not iterable

# %%
for number in numbers:
    if number == [2, 2]:
        print(True)

# %% [markdown]
# Q5

# %%
def python(python_is_fun, python_is_weird): 
    if(python_is_fun = True and python_is_weird = True) or (python_is_fun = True or python_is_weird = True)
        print "Woo Python!"
    else:
        print "Python is not for me!"
# Out:
#   File "<ipython-input-128-4cb29a127c9e>", line 2
#     if(python_is_fun = True and python_is_weird = True) or (python_is_fun = True or python_is_weird = True)
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q6

# %%
chickens = [
  { "name": "Margaret", "age": 2, "eggs": 0 },
  { "name": "Hetty", "age": 1, "eggs": 2 },
  { "name": "Henrietta", "age": 3, "eggs": 1 },
  { "name": "Audrey", "age": 2, "eggs": 0 },
  { "name": "Mabel", "age": 5, "eggs": 1 },
]

# %%
total_eggs = 0

for chicken in chickens:
    total_eggs += chicken["eggs"]
    chicken["eggs"] = 0 # eggs have been collected

print(f"{total_eggs} eggs collected")
# Out:
# 4 eggs collected

# %%
def count_eggs(chickens):
    total_eggs = 0

    for birds in chickens:
        total_eggs += birds["eggs"]
        birds["eggs"] = 0 # eggs have been collected

    return f"{total_eggs} eggs collected"

print(count_eggs(chickens))
# Out:
# 4 eggs collected
